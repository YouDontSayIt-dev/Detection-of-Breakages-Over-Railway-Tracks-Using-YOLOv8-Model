# %% [markdown]
# ## Setup

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from tensorflow import keras
from keras.applications.vgg16 import VGG16
from keras.applications.resnet50 import ResNet50
from keras.applications.inception_v3 import InceptionV3
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Define Input Size

# %%
IMAGE_SIZE = [224, 224]

# %% [markdown]
# # Install Roboflow

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="j4oHBD3msAlUlJvXwsHz")
project = rf.workspace("thesis-group").project("railway-crack-detection-imgcl")
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.9-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: certifi==2023.7.22 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2023.7.22)
# Collecting chardet==4.0.0 (from roboflow)
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 6.9 MB/s eta 0:00:00
# Collecting cycler==0.10.0 (from roboflow)
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting idna==2.10 (from roboflow)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.23.5)
# Collecting opencv-python-headless==4.8.0.74 (from roboflow)
#   Downloading opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 18.4 MB/s eta 0:00:00
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Collecting pyparsing==2.4.7 (from roboflow)
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Collecting supervision (from roboflow)
#   Downloading supervision-0.16.0-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.0.7)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.5 MB/s eta 0:00:00
# Collecting python-magic (from roboflow)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.44.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.3.2)
# Requirement already satisfied: scipy<2.0.0,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from supervision->roboflow) (1.11.3)
# Installing collected packages: python-magic, python-dotenv, pyparsing, opencv-python-headless, idna, cycler, chardet, supervision, requests-toolbelt, roboflow
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
#     Uninstalling opencv-python-headless-4.8.1.78:
#       Successfully uninstalled opencv-python-headless-4.8.1.78
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
# Successfully installed chardet-4.0.0 cycler-0.10.0 idna-2.10 opencv-python-headless-4.8.0.74 pyparsing-2.4.7 python-dotenv-1.0.0 python-magic-0.4.27 requests-toolbelt-1.0.0 roboflow-1.1.9 supervision-0.16.0
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# ## Dataset

# %%
train_path = '/content/drive/MyDrive/ThesisData/Keras/train'
valid_path = '/content/drive/MyDrive/ThesisData/Keras/valid'
test_path = '/content/drive/MyDrive/ThesisData/Keras/test'

# %%
trdata = ImageDataGenerator()
traindata = trdata.flow_from_directory(directory=train_path,batch_size=13,class_mode='categorical',target_size=(224,224))
vdata = ImageDataGenerator()
valdata = vdata.flow_from_directory(directory=valid_path,batch_size=13,class_mode='categorical',target_size=(224,224))
tdata = ImageDataGenerator()
testdata = tdata.flow_from_directory(directory=valid_path,batch_size=13,class_mode='categorical',target_size=(224,224))
# Out:
# Found 1923 images belonging to 2 classes.
# Found 180 images belonging to 2 classes.
# Found 180 images belonging to 2 classes.

# %% [markdown]
# ## Model

# %%
pre_trained_model = ResNet50(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step

# %%
for layer in pre_trained_model.layers:
  layer.trainable = False

# %%
from tensorflow.keras import layers, models

flatten_layer = layers.Flatten()
dense_layer_1 = layers.Dense(50, activation='relu')
dense_layer_2 = layers.Dense(20, activation='relu')
prediction_layer = layers.Dense(2, activation='softmax')
model = keras.models.Sequential([
    pre_trained_model,
    flatten_layer,
    dense_layer_1,
    dense_layer_2,
    prediction_layer
                                 ])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  flatten_1 (Flatten)         (None, 100352)            0
#
#  dense_1 (Dense)             (None, 50)                5017650
#
#  dense_2 (Dense)             (None, 20)                1020
#
#  dense_3 (Dense)             (None, 2)                 42
#
# =================================================================
# Total params: 28606424 (109.12 MB)
# Trainable params: 5018712 (19.14 MB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________

# %%
# Lets fit our model
# Optimization
from tensorflow.keras.optimizers import Adam

opt = Adam(1e-4)

# %%
model.compile(loss='categorical_crossentropy',optimizer=opt, metrics = ['accuracy'])

# %% [markdown]
# ## Training

# %%
from datetime import datetime
from keras.callbacks import ModelCheckpoint



checkpoint = ModelCheckpoint(filepath='mymodel.h5',
                               verbose=2, save_best_only=True)

callbacks = [checkpoint]

start = datetime.now()

model_history=model.fit(
  traindata,
  validation_data=valdata,
  epochs=100,
  callbacks=callbacks ,verbose=2)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.30659, saving model to mymodel.h5
# 148/148 - 30s - loss: 0.3717 - accuracy: 0.8560 - val_loss: 0.3066 - val_accuracy: 0.9056 - 30s/epoch - 204ms/step
# Epoch 2/100
#
# Epoch 2: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 0.0609 - accuracy: 0.9823 - val_loss: 0.3502 - val_accuracy: 0.9000 - 26s/epoch - 172ms/step
# Epoch 3/100
#
# Epoch 3: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 0.0172 - accuracy: 0.9969 - val_loss: 0.3902 - val_accuracy: 0.8944 - 26s/epoch - 178ms/step
# Epoch 4/100
#
# Epoch 4: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 0.0082 - accuracy: 0.9990 - val_loss: 0.3270 - val_accuracy: 0.9222 - 26s/epoch - 173ms/step
# Epoch 5/100
#
# Epoch 5: val_loss did not improve from 0.30659
# 148/148 - 25s - loss: 0.0187 - accuracy: 0.9995 - val_loss: 0.3264 - val_accuracy: 0.9222 - 25s/epoch - 170ms/step
# Epoch 6/100
#
# Epoch 6: val_loss did not improve from 0.30659
# 148/148 - 25s - loss: 0.0081 - accuracy: 0.9990 - val_loss: 0.3237 - val_accuracy: 0.9222 - 25s/epoch - 171ms/step
# Epoch 7/100
#
# Epoch 7: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.3862 - val_accuracy: 0.9222 - 26s/epoch - 172ms/step
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 5.1204e-04 - accuracy: 1.0000 - val_loss: 0.4040 - val_accuracy: 0.9222 - 24s/epoch - 161ms/step
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 0.30659
# 148/148 - 23s - loss: 3.9777e-04 - accuracy: 1.0000 - val_loss: 0.4167 - val_accuracy: 0.9222 - 23s/epoch - 158ms/step
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 3.2147e-04 - accuracy: 1.0000 - val_loss: 0.4288 - val_accuracy: 0.9222 - 24s/epoch - 163ms/step
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 2.5668e-04 - accuracy: 1.0000 - val_loss: 0.4168 - val_accuracy: 0.9167 - 26s/epoch - 178ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.30659
# 148/148 - 23s - loss: 2.1220e-04 - accuracy: 1.0000 - val_loss: 0.4321 - val_accuracy: 0.9167 - 23s/epoch - 158ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 1.7457e-04 - accuracy: 1.0000 - val_loss: 0.4359 - val_accuracy: 0.9167 - 24s/epoch - 165ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 1.4644e-04 - accuracy: 1.0000 - val_loss: 0.4519 - val_accuracy: 0.9222 - 24s/epoch - 162ms/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.30659
# 148/148 - 23s - loss: 1.2485e-04 - accuracy: 1.0000 - val_loss: 0.4586 - val_accuracy: 0.9222 - 23s/epoch - 158ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 1.0785e-04 - accuracy: 1.0000 - val_loss: 0.4590 - val_accuracy: 0.9222 - 24s/epoch - 161ms/step
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 9.3252e-05 - accuracy: 1.0000 - val_loss: 0.4607 - val_accuracy: 0.9278 - 24s/epoch - 165ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 8.2047e-05 - accuracy: 1.0000 - val_loss: 0.4728 - val_accuracy: 0.9278 - 24s/epoch - 162ms/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 7.3091e-05 - accuracy: 1.0000 - val_loss: 0.4715 - val_accuracy: 0.9278 - 24s/epoch - 165ms/step
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 6.5264e-05 - accuracy: 1.0000 - val_loss: 0.4742 - val_accuracy: 0.9278 - 24s/epoch - 160ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.30659
# 148/148 - 23s - loss: 5.7422e-05 - accuracy: 1.0000 - val_loss: 0.4792 - val_accuracy: 0.9278 - 23s/epoch - 158ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 5.1416e-05 - accuracy: 1.0000 - val_loss: 0.4851 - val_accuracy: 0.9278 - 24s/epoch - 164ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 4.6545e-05 - accuracy: 1.0000 - val_loss: 0.4863 - val_accuracy: 0.9278 - 24s/epoch - 164ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 4.2340e-05 - accuracy: 1.0000 - val_loss: 0.4915 - val_accuracy: 0.9278 - 24s/epoch - 165ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 3.7879e-05 - accuracy: 1.0000 - val_loss: 0.4974 - val_accuracy: 0.9278 - 24s/epoch - 163ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 3.4326e-05 - accuracy: 1.0000 - val_loss: 0.4980 - val_accuracy: 0.9278 - 24s/epoch - 160ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 3.1225e-05 - accuracy: 1.0000 - val_loss: 0.5050 - val_accuracy: 0.9278 - 26s/epoch - 178ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 2.8391e-05 - accuracy: 1.0000 - val_loss: 0.5073 - val_accuracy: 0.9278 - 24s/epoch - 164ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 2.5769e-05 - accuracy: 1.0000 - val_loss: 0.5182 - val_accuracy: 0.9278 - 24s/epoch - 163ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 2.3664e-05 - accuracy: 1.0000 - val_loss: 0.5114 - val_accuracy: 0.9278 - 24s/epoch - 165ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 2.1509e-05 - accuracy: 1.0000 - val_loss: 0.5238 - val_accuracy: 0.9278 - 26s/epoch - 175ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 1.9712e-05 - accuracy: 1.0000 - val_loss: 0.5204 - val_accuracy: 0.9278 - 26s/epoch - 175ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 1.8112e-05 - accuracy: 1.0000 - val_loss: 0.5205 - val_accuracy: 0.9278 - 26s/epoch - 178ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.30659
# 148/148 - 23s - loss: 1.6622e-05 - accuracy: 1.0000 - val_loss: 0.5275 - val_accuracy: 0.9278 - 23s/epoch - 158ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 1.5299e-05 - accuracy: 1.0000 - val_loss: 0.5234 - val_accuracy: 0.9278 - 24s/epoch - 163ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 1.3925e-05 - accuracy: 1.0000 - val_loss: 0.5296 - val_accuracy: 0.9278 - 24s/epoch - 164ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 1.2925e-05 - accuracy: 1.0000 - val_loss: 0.5309 - val_accuracy: 0.9278 - 24s/epoch - 164ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 1.1975e-05 - accuracy: 1.0000 - val_loss: 0.5325 - val_accuracy: 0.9278 - 24s/epoch - 163ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.30659
# 148/148 - 25s - loss: 1.1006e-05 - accuracy: 1.0000 - val_loss: 0.5366 - val_accuracy: 0.9278 - 25s/epoch - 168ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.30659
# 148/148 - 27s - loss: 1.0086e-05 - accuracy: 1.0000 - val_loss: 0.5368 - val_accuracy: 0.9278 - 27s/epoch - 184ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 9.3830e-06 - accuracy: 1.0000 - val_loss: 0.5497 - val_accuracy: 0.9278 - 26s/epoch - 175ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 0.30659
# 148/148 - 27s - loss: 8.6962e-06 - accuracy: 1.0000 - val_loss: 0.5424 - val_accuracy: 0.9278 - 27s/epoch - 183ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.30659
# 148/148 - 28s - loss: 8.0135e-06 - accuracy: 1.0000 - val_loss: 0.5485 - val_accuracy: 0.9278 - 28s/epoch - 190ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.30659
# 148/148 - 28s - loss: 7.4109e-06 - accuracy: 1.0000 - val_loss: 0.5492 - val_accuracy: 0.9278 - 28s/epoch - 189ms/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 0.30659
# 148/148 - 28s - loss: 6.8493e-06 - accuracy: 1.0000 - val_loss: 0.5533 - val_accuracy: 0.9278 - 28s/epoch - 189ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 0.30659
# 148/148 - 29s - loss: 6.3233e-06 - accuracy: 1.0000 - val_loss: 0.5596 - val_accuracy: 0.9222 - 29s/epoch - 197ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 0.30659
# 148/148 - 29s - loss: 5.8364e-06 - accuracy: 1.0000 - val_loss: 0.5669 - val_accuracy: 0.9222 - 29s/epoch - 195ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 0.30659
# 148/148 - 29s - loss: 5.4265e-06 - accuracy: 1.0000 - val_loss: 0.5709 - val_accuracy: 0.9222 - 29s/epoch - 194ms/step
# Epoch 49/100
#
# Epoch 49: val_loss did not improve from 0.30659
# 148/148 - 27s - loss: 5.0234e-06 - accuracy: 1.0000 - val_loss: 0.5764 - val_accuracy: 0.9222 - 27s/epoch - 184ms/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 4.5999e-06 - accuracy: 1.0000 - val_loss: 0.5733 - val_accuracy: 0.9222 - 26s/epoch - 179ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.30659
# 148/148 - 27s - loss: 4.2773e-06 - accuracy: 1.0000 - val_loss: 0.5827 - val_accuracy: 0.9222 - 27s/epoch - 184ms/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 3.9741e-06 - accuracy: 1.0000 - val_loss: 0.5738 - val_accuracy: 0.9222 - 26s/epoch - 176ms/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.30659
# 148/148 - 27s - loss: 3.6721e-06 - accuracy: 1.0000 - val_loss: 0.5799 - val_accuracy: 0.9222 - 27s/epoch - 185ms/step
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 3.3738e-06 - accuracy: 1.0000 - val_loss: 0.5939 - val_accuracy: 0.9167 - 26s/epoch - 173ms/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 3.1556e-06 - accuracy: 1.0000 - val_loss: 0.6052 - val_accuracy: 0.9167 - 26s/epoch - 177ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.30659
# 148/148 - 27s - loss: 2.9053e-06 - accuracy: 1.0000 - val_loss: 0.5918 - val_accuracy: 0.9222 - 27s/epoch - 183ms/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 2.6869e-06 - accuracy: 1.0000 - val_loss: 0.6007 - val_accuracy: 0.9167 - 26s/epoch - 172ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 2.4844e-06 - accuracy: 1.0000 - val_loss: 0.6060 - val_accuracy: 0.9167 - 24s/epoch - 160ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.30659
# 148/148 - 25s - loss: 2.2992e-06 - accuracy: 1.0000 - val_loss: 0.6115 - val_accuracy: 0.9167 - 25s/epoch - 166ms/step
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 0.30659
# 148/148 - 23s - loss: 2.1378e-06 - accuracy: 1.0000 - val_loss: 0.6114 - val_accuracy: 0.9167 - 23s/epoch - 157ms/step
# Epoch 61/100
#
# Epoch 61: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 1.9726e-06 - accuracy: 1.0000 - val_loss: 0.6130 - val_accuracy: 0.9167 - 24s/epoch - 164ms/step
# Epoch 62/100
#
# Epoch 62: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 1.8509e-06 - accuracy: 1.0000 - val_loss: 0.6131 - val_accuracy: 0.9167 - 24s/epoch - 163ms/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 1.6897e-06 - accuracy: 1.0000 - val_loss: 0.6213 - val_accuracy: 0.9167 - 24s/epoch - 165ms/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 1.5704e-06 - accuracy: 1.0000 - val_loss: 0.6220 - val_accuracy: 0.9167 - 26s/epoch - 174ms/step
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 1.4485e-06 - accuracy: 1.0000 - val_loss: 0.6213 - val_accuracy: 0.9167 - 24s/epoch - 165ms/step
# Epoch 66/100
#
# Epoch 66: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 1.3464e-06 - accuracy: 1.0000 - val_loss: 0.6230 - val_accuracy: 0.9167 - 26s/epoch - 178ms/step
# Epoch 67/100
#
# Epoch 67: val_loss did not improve from 0.30659
# 148/148 - 27s - loss: 1.2481e-06 - accuracy: 1.0000 - val_loss: 0.6258 - val_accuracy: 0.9167 - 27s/epoch - 182ms/step
# Epoch 68/100
#
# Epoch 68: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 1.1588e-06 - accuracy: 1.0000 - val_loss: 0.6340 - val_accuracy: 0.9167 - 26s/epoch - 178ms/step
# Epoch 69/100
#
# Epoch 69: val_loss did not improve from 0.30659
# 148/148 - 28s - loss: 1.0778e-06 - accuracy: 1.0000 - val_loss: 0.6365 - val_accuracy: 0.9167 - 28s/epoch - 186ms/step
# Epoch 70/100
#
# Epoch 70: val_loss did not improve from 0.30659
# 148/148 - 25s - loss: 9.8888e-07 - accuracy: 1.0000 - val_loss: 0.6453 - val_accuracy: 0.9167 - 25s/epoch - 171ms/step
# Epoch 71/100
#
# Epoch 71: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 9.2261e-07 - accuracy: 1.0000 - val_loss: 0.6346 - val_accuracy: 0.9167 - 26s/epoch - 175ms/step
# Epoch 72/100
#
# Epoch 72: val_loss did not improve from 0.30659
# 148/148 - 28s - loss: 8.4711e-07 - accuracy: 1.0000 - val_loss: 0.6427 - val_accuracy: 0.9167 - 28s/epoch - 186ms/step
# Epoch 73/100
#
# Epoch 73: val_loss did not improve from 0.30659
# 148/148 - 27s - loss: 7.8493e-07 - accuracy: 1.0000 - val_loss: 0.6441 - val_accuracy: 0.9167 - 27s/epoch - 184ms/step
# Epoch 74/100
#
# Epoch 74: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 7.3267e-07 - accuracy: 1.0000 - val_loss: 0.6513 - val_accuracy: 0.9167 - 24s/epoch - 163ms/step
# Epoch 75/100
#
# Epoch 75: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 6.7961e-07 - accuracy: 1.0000 - val_loss: 0.6552 - val_accuracy: 0.9167 - 26s/epoch - 175ms/step
# Epoch 76/100
#
# Epoch 76: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 6.2741e-07 - accuracy: 1.0000 - val_loss: 0.6494 - val_accuracy: 0.9167 - 26s/epoch - 177ms/step
# Epoch 77/100
#
# Epoch 77: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 5.8241e-07 - accuracy: 1.0000 - val_loss: 0.6542 - val_accuracy: 0.9167 - 26s/epoch - 173ms/step
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 5.3529e-07 - accuracy: 1.0000 - val_loss: 0.6590 - val_accuracy: 0.9167 - 24s/epoch - 164ms/step
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 4.9308e-07 - accuracy: 1.0000 - val_loss: 0.6648 - val_accuracy: 0.9167 - 24s/epoch - 162ms/step
# Epoch 80/100
#
# Epoch 80: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 4.6109e-07 - accuracy: 1.0000 - val_loss: 0.6658 - val_accuracy: 0.9167 - 24s/epoch - 164ms/step
# Epoch 81/100
#
# Epoch 81: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 4.2948e-07 - accuracy: 1.0000 - val_loss: 0.6697 - val_accuracy: 0.9167 - 24s/epoch - 164ms/step
# Epoch 82/100
#
# Epoch 82: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 3.9488e-07 - accuracy: 1.0000 - val_loss: 0.6725 - val_accuracy: 0.9167 - 26s/epoch - 174ms/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 3.6879e-07 - accuracy: 1.0000 - val_loss: 0.6797 - val_accuracy: 0.9167 - 26s/epoch - 175ms/step
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.30659
# 148/148 - 24s - loss: 3.3959e-07 - accuracy: 1.0000 - val_loss: 0.6704 - val_accuracy: 0.9167 - 24s/epoch - 165ms/step
# Epoch 85/100
#
# Epoch 85: val_loss did not improve from 0.30659
# 148/148 - 23s - loss: 3.1535e-07 - accuracy: 1.0000 - val_loss: 0.6768 - val_accuracy: 0.9167 - 23s/epoch - 155ms/step
# Epoch 86/100
#
# Epoch 86: val_loss did not improve from 0.30659
# 148/148 - 25s - loss: 2.8987e-07 - accuracy: 1.0000 - val_loss: 0.6738 - val_accuracy: 0.9167 - 25s/epoch - 166ms/step
# Epoch 87/100
#
# Epoch 87: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 2.6656e-07 - accuracy: 1.0000 - val_loss: 0.6815 - val_accuracy: 0.9167 - 26s/epoch - 172ms/step
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 2.4747e-07 - accuracy: 1.0000 - val_loss: 0.6760 - val_accuracy: 0.9167 - 26s/epoch - 178ms/step
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 0.30659
# 148/148 - 25s - loss: 2.3055e-07 - accuracy: 1.0000 - val_loss: 0.6853 - val_accuracy: 0.9167 - 25s/epoch - 169ms/step
# Epoch 90/100
#
# Epoch 90: val_loss did not improve from 0.30659
# 148/148 - 27s - loss: 2.1238e-07 - accuracy: 1.0000 - val_loss: 0.6941 - val_accuracy: 0.9167 - 27s/epoch - 183ms/step
# Epoch 91/100
#
# Epoch 91: val_loss did not improve from 0.30659
# 148/148 - 27s - loss: 1.9564e-07 - accuracy: 1.0000 - val_loss: 0.6924 - val_accuracy: 0.9167 - 27s/epoch - 181ms/step
# Epoch 92/100
#
# Epoch 92: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 1.8213e-07 - accuracy: 1.0000 - val_loss: 0.6840 - val_accuracy: 0.9222 - 26s/epoch - 177ms/step
# Epoch 93/100
#
# Epoch 93: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 1.6775e-07 - accuracy: 1.0000 - val_loss: 0.6922 - val_accuracy: 0.9222 - 26s/epoch - 177ms/step
# Epoch 94/100
#
# Epoch 94: val_loss did not improve from 0.30659
# 148/148 - 27s - loss: 1.5498e-07 - accuracy: 1.0000 - val_loss: 0.7114 - val_accuracy: 0.9167 - 27s/epoch - 183ms/step
# Epoch 95/100
#
# Epoch 95: val_loss did not improve from 0.30659
# 148/148 - 28s - loss: 1.4208e-07 - accuracy: 1.0000 - val_loss: 0.7109 - val_accuracy: 0.9167 - 28s/epoch - 186ms/step
# Epoch 96/100
#
# Epoch 96: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 1.3204e-07 - accuracy: 1.0000 - val_loss: 0.7003 - val_accuracy: 0.9222 - 26s/epoch - 177ms/step
# Epoch 97/100
#
# Epoch 97: val_loss did not improve from 0.30659
# 148/148 - 27s - loss: 1.2169e-07 - accuracy: 1.0000 - val_loss: 0.7068 - val_accuracy: 0.9167 - 27s/epoch - 184ms/step
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.30659
# 148/148 - 25s - loss: 1.1332e-07 - accuracy: 1.0000 - val_loss: 0.7114 - val_accuracy: 0.9167 - 25s/epoch - 170ms/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 1.0371e-07 - accuracy: 1.0000 - val_loss: 0.7158 - val_accuracy: 0.9167 - 26s/epoch - 178ms/step
# Epoch 100/100
#
# Epoch 100: val_loss did not improve from 0.30659
# 148/148 - 26s - loss: 9.4723e-08 - accuracy: 1.0000 - val_loss: 0.7175 - val_accuracy: 0.9167 - 26s/epoch - 179ms/step
# Training completed in time:  0:49:37.456365

# %%
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('Resnet-50 accuracy values')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(model_history.history['loss'], label='Training Loss (training data)')
plt.plot(model_history.history['val_loss'], label='Validation Loss (validation data)')
plt.title('Resnet-50 Loss for Railway Cracks')
plt.ylabel('Loss value')
plt.xlabel('No. epoch')
plt.legend(loc="upper left")
plt.show()

# %%
model.save('resnet-50-cracks.keras')

# %% [markdown]
# # Deploy model on roboflow

# %%
project.version(1).deploy(model_type="Resnet-50", model_path="/content/drive/MyDrive/ThesisData/Keras/KerasModels/resnet-50-cracks.keras")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-0abfd309008b> in <cell line: 1>()
# ----> 1 project.version(1).deploy(model_type="Resnet-50", model_path="/content/drive/MyDrive/ThesisData/Keras/KerasModels/resnet-50-cracks.keras")
#
# /usr/local/lib/python3.10/dist-packages/roboflow/core/version.py in deploy(self, model_type, model_path)
#     469             supported_model in model_type for supported_model in supported_models
#     470         ):
# --> 471             raise (
#     472                 ValueError(
#     473                     f"Model type {model_type} not supported. Supported models are {supported_models}"
#
# ValueError: Model type Resnet-50 not supported. Supported models are ['yolov5', 'yolov7-seg', 'yolov8']

# %% [markdown]
# ## Testing

# %%
from keras.models import load_model
from google.colab.patches import cv2_imshow
trainedModel = load_model('/content/resnet-50-cracks.keras')

# Define class names
class_names = ['cracks', 'nocracks']
testCrack_path = '/content/drive/MyDrive/ThesisData/Keras/test/crack'
testNoncrack_path = '/content/drive/MyDrive/ThesisData/Keras/test/nocrack'

# %% [markdown]
# Single Image Prediction

# %%
from google.colab.patches import cv2_imshow

img = cv2.imread("/content/drive/MyDrive/ThesisData/Keras/test/crack/Image-081_jpg.rf.396b72611e16c2b95ed58be25e1e4670.jpg")
image_resized= cv2.resize(img, (224,224))
cv2_imshow(img)
cv2.waitKey(0)
img=np.expand_dims(image_resized,axis=0)
print(img.shape)
class_names = ['cracks','nocracks']

pred=trainedModel.predict(img)
pr_cl=np.argmax(pred,axis=1)
output_class=class_names[np.argmax(pred)]

print("The predicted class is", output_class)

# %% [markdown]
# Multiple Image Prediction

# %%
from google.colab.patches import cv2_imshow
import cv2

# Initialize a dictionary to count the number of images per class
class_counts = {class_name: 0 for class_name in class_names}


# List all image files in the folder
image_files = [f for f in os.listdir(testCrack_path) if f.endswith(".jpg")]

for image_file in image_files:
    image_path = os.path.join(testCrack_path, image_file)
    img = cv2.imread(image_path)
    image_resized = cv2.resize(img, (224, 224))
    cv2_imshow(image_resized)
    cv2.waitKey(0)
    img = np.expand_dims(image_resized, axis=0)
    print("Image shape:", img.shape)

    # Make predictions
    pred = trainedModel.predict(img)
    predicted_class_index = np.argmax(pred)
    output_class = class_names[predicted_class_index]

    # Update the class count
    class_counts[output_class] += 1

    print("Predicted class:", output_class)
    print("Class probabilities:", pred)
    print("\n")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Count how many per class predictions

# %%
# Print the counts for each class
for class_name, count in class_counts.items():
    print(f"Count of {class_name}: {count}")
# Out:
# Count of cracks: 68
# Count of nocracks: 1
